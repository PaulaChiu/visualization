# %%
import numpy as np
import pandas as pd
import calmap

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
np.random.seed(sum(map(ord, 'calmap')))

# %%
all_days = pd.date_range('1/15/2014', periods=700, freq='D')
days = np.random.choice(all_days, 500)
events = pd.Series(np.random.randn(len(days)), index=days)

# %%
calmap.calendarplot(events, monthticks=3, daylabels='MTWTFSS',
                    dayticks=[0, 2, 4, 6], cmap='YlGn',
                    fillcolor='grey', linewidth=0,
                    fig_kws=dict(figsize=(8, 4)))
# Out:
# (<matplotlib.figure.Figure at 0x278961b2ef0>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000278966550B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000278962FF518>],
#        dtype=object))

# %%
plt.figure(figsize=(20,10))
calmap.yearplot(events, year=2015)

# %% [markdown]
# ##### more examples

# %%
calmap.yearplot(events, year=2015)

# %%
calmap.yearplot(events, cmap='YlGn', fillcolor='grey',
                linewidth=0)

# %%
calmap.yearplot(events, monthticks=3, daylabels='MTWTFSS',
                dayticks=[0, 2, 4, 6])
