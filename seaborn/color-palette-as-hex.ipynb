# %% [markdown]
# https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
import seaborn as sns

# %%
sns.set(rc={"figure.figsize": (6,8)})
current_palette = sns.color_palette()
sns.palplot(current_palette)

# %% [markdown]
# ### Using circular color systems

# %%
sns.palplot(sns.color_palette("hls", 8))

# %%
sns.palplot(sns.hls_palette(8, l=.3, s=.8))

# %% [markdown]
# ### Using categorical Color Brewer palettes

# %%
sns.palplot(sns.color_palette("Set2"))

# %%
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]
sns.palplot(sns.color_palette(flatui))

# %% [markdown]
# ### Sequential “cubehelix” palettes

# %%
sns.palplot(sns.color_palette("cubehelix", 8))

# %%
sns.palplot(sns.color_palette("cubehelix", 20))

# %%
sns.palplot(sns.color_palette("cubehelix", 50))

# %%
sns.palplot(sns.cubehelix_palette(8))

# %% [markdown]
# ### Sequential color palettes

# %%
sns.palplot(sns.color_palette("Blues"))

# %%
sns.palplot(sns.color_palette("GnBu_d"))

# %% [markdown]
# ### Diverging color palettes

# %%
sns.palplot(sns.color_palette("BrBG", 7))

# %%
sns.palplot(sns.color_palette("RdBu_r", 7))

# %%
sns.palplot(sns.color_palette("coolwarm", 7))

# %% [markdown]
# ### Custom diverging palettes

# %%
sns.palplot(sns.diverging_palette(220, 20, n=7))

# %%
sns.palplot(sns.diverging_palette(145, 280, s=85, l=25, n=7))

# %%
sns.palplot(sns.diverging_palette(10, 220, sep=80, n=7))

# %%
sns.palplot(sns.diverging_palette(255, 133, l=60, n=7, center="dark"))

# %%
sns.palplot(sns.color_palette("RdBu", n_colors=7))

# %% [markdown]
# ###### as hex method

# %%
pal = sns.color_palette("RdBu", n_colors=7)

# %%
pal.as_hex()
# Out:
# [u'#bb2a34',
#  u'#e58368',
#  u'#fbceb7',
#  u'#f6f7f7',
#  u'#c0dceb',
#  u'#68abd0',
#  u'#2870b1']

# %% [markdown]
# ###### or

# %%
pal_hls = sns.hls_palette(12, l=.3, s=.8).as_hex()

# %%
print(pal_hls);
# Out:
# [u'#8a170f', u'#8a540f', u'#828a0f', u'#458a0f', u'#0f8a17', u'#0f8a54', u'#0f828a', u'#0f458a', u'#170f8a', u'#540f8a', u'#8a0f82', u'#8a0f45']

# %% [markdown]
# ##### more

# %%
cube = sns.color_palette("cubehelix", 20)

# %%
cube.as_hex()
# Out:
# [u'#110815',
#  u'#19132d',
#  u'#1a2441',
#  u'#17374d',
#  u'#154d4e',
#  u'#1b6145',
#  u'#2b6f39',
#  u'#467830',
#  u'#697b30',
#  u'#8d7a3d',
#  u'#b17959',
#  u'#c87b7c',
#  u'#d382a3',
#  u'#d490c6',
#  u'#cda2e0',
#  u'#c5baf0',
#  u'#c1cff3',
#  u'#c6e1f1',
#  u'#d4efef',
#  u'#e9f8f2']

# %%
sns.palplot(sns.color_palette("cubehelix", 20))
