# %%
import pandas as pd
import numpy as np

# %%
DF_GAPMINDER = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/gapminderDataFiveYear.csv')

# %%
DF_GAPMINDER.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
# country      1704 non-null object
# year         1704 non-null int64
# pop          1704 non-null float64
# continent    1704 non-null object
# lifeExp      1704 non-null float64
# gdpPercap    1704 non-null float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 80.0+ KB

# %%
DF_GAPMINDER.head()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %%
DF_GAPMINDER.tail()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 1699  Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700  Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701  Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702  Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703  Zimbabwe  2007  12311143.0    Africa   43.487  469.709298

# %%
DF_GAPMINDER_YYYY = DF_GAPMINDER[DF_GAPMINDER['year'] == 2007]

# %%
DF_GAPMINDER_YYYY
# Out:
#                        country  year           pop continent  lifeExp  \
# 11                 Afghanistan  2007  3.188992e+07      Asia   43.828
# 23                     Albania  2007  3.600523e+06    Europe   76.423
# 35                     Algeria  2007  3.333322e+07    Africa   72.301
# 47                      Angola  2007  1.242048e+07    Africa   42.731
# 59                   Argentina  2007  4.030193e+07  Americas   75.320
# 71                   Australia  2007  2.043418e+07   Oceania   81.235
# 83                     Austria  2007  8.199783e+06    Europe   79.829
# 95                     Bahrain  2007  7.085730e+05      Asia   75.635
# 107                 Bangladesh  2007  1.504483e+08      Asia   64.062
# 119                    Belgium  2007  1.039223e+07    Europe   79.441
# 131                      Benin  2007  8.078314e+06    Africa   56.728
# 143                    Bolivia  2007  9.119152e+06  Americas   65.554
# ...

# %%
DF_GAPMINDER.loc[0:20]
# Out:
#         country  year         pop continent  lifeExp    gdpPercap
# 0   Afghanistan  1952   8425333.0      Asia   28.801   779.445314
# 1   Afghanistan  1957   9240934.0      Asia   30.332   820.853030
# 2   Afghanistan  1962  10267083.0      Asia   31.997   853.100710
# 3   Afghanistan  1967  11537966.0      Asia   34.020   836.197138
# 4   Afghanistan  1972  13079460.0      Asia   36.088   739.981106
# 5   Afghanistan  1977  14880372.0      Asia   38.438   786.113360
# 6   Afghanistan  1982  12881816.0      Asia   39.854   978.011439
# 7   Afghanistan  1987  13867957.0      Asia   40.822   852.395945
# 8   Afghanistan  1992  16317921.0      Asia   41.674   649.341395
# 9   Afghanistan  1997  22227415.0      Asia   41.763   635.341351
# 10  Afghanistan  2002  25268405.0      Asia   42.129   726.734055
# 11  Afghanistan  2007  31889923.0      Asia   43.828   974.580338
# 12      Albania  1952   1282697.0    Europe   55.230  1601.056136
# ...

# %%
ROWS = [
    {'a': 'AA', 'b': 1},
    {'a': 'AB', 'b': 2},
    {'a': 'BB', 'b': 3},
    {'a': 'BC', 'b': 4},
    {'a': 'CC', 'b': 5},
    {'a': 'CD', 'b': 6}
]

# %%
ROWS
# Out:
# [{'a': 'AA', 'b': 1},
#  {'a': 'AB', 'b': 2},
#  {'a': 'BB', 'b': 3},
#  {'a': 'BC', 'b': 4},
#  {'a': 'CC', 'b': 5},
#  {'a': 'CD', 'b': 6}]

# %%
rows = DF_GAPMINDER_YYYY.to_dict('records')

# %%
rows
# Out:
# [{'continent': 'Asia',
#   'country': 'Afghanistan',
#   'gdpPercap': 974.5803384,
#   'lifeExp': 43.828,
#   'pop': 31889923.0,
#   'year': 2007},
#  {'continent': 'Europe',
#   'country': 'Albania',
#   'gdpPercap': 5937.029525999999,
#   'lifeExp': 76.423,
#   'pop': 3600523.0,
#   'year': 2007},
#  {'continent': 'Africa',
#   'country': 'Algeria',
#   'gdpPercap': 6223.367465,
#   'lifeExp': 72.301,
#   'pop': 33333216.0,
#   'year': 2007},
#  {'continent': 'Africa',
#   'country': 'Angola',
#   'gdpPercap': 4797.231267,
#   'lifeExp': 42.731,
#   'pop': 12420476.0,
#   'year': 2007},
#  {'continent': 'Americas',
#   'country': 'Argentina',
#   'gdpPercap': 12779.379640000001,
#   'lifeExp': 75.32,
#   'pop': 40301927.0,
#   'year': 2007},
#  {'continent': 'Oceania',
#   'country': 'Australia',
#   'gdpPercap': 34435.367439999995,
#   'lifeExp': 81.235,
#   'pop': 20434176.0,
#   'year': 2007},
#  {'continent': 'Europe',
#   'country': 'Austria',
#   'gdpPercap': 36126.4927,
# ...

# %%
dff = pd.DataFrame(rows)

# %%
dff
# Out:
#     continent                   country     gdpPercap  lifeExp           pop  \
# 0        Asia               Afghanistan    974.580338   43.828  3.188992e+07
# 1      Europe                   Albania   5937.029526   76.423  3.600523e+06
# 2      Africa                   Algeria   6223.367465   72.301  3.333322e+07
# 3      Africa                    Angola   4797.231267   42.731  1.242048e+07
# 4    Americas                 Argentina  12779.379640   75.320  4.030193e+07
# 5     Oceania                 Australia  34435.367440   81.235  2.043418e+07
# 6      Europe                   Austria  36126.492700   79.829  8.199783e+06
# 7        Asia                   Bahrain  29796.048340   75.635  7.085730e+05
# 8        Asia                Bangladesh   1391.253792   64.062  1.504483e+08
# 9      Europe                   Belgium  33692.605080   79.441  1.039223e+07
# 10     Africa                     Benin   1441.284873   56.728  8.078314e+06
# ...
