# %% [markdown]
# https://plot.ly/python/

# %% [markdown]
# https://plot.ly/ipython-notebooks/

# %%
import plotly
plotly.__version__

# %%
import pandas as pd
import numpy as np
import scipy as sp
import plotly.plotly as py

# %%
import plotly.plotly as py
import plotly.figure_factory as ff
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")

table = ff.create_table(df)
py.iplot(table, filename='jupyter/table1')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-ef208f0f2e75> in <module>()
#       1 import plotly.plotly as py
# ----> 2 import plotly.figure_factory as ff
#       3 import pandas as pd
#       4
#       5 df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")
#
# ImportError: No module named figure_factory

# %%
import plotly.plotly as py
from plotly.graph_objs import *

# %%
df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 4 columns):
# School    21 non-null object
# Women     21 non-null int64
# Men       21 non-null int64
# gap       21 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 744.0+ bytes

# %%
data = [Bar(x=df.School,
            y=df.gap)]

py.iplot(data, filename='jupyter/basic_bar')
# Out:
# Aw, snap! We don't have an account for ''. Want to try again? You can authenticate with your email address or username. Sign in is not case sensitive.
#
# Don't have an account? plot.ly
#
# Questions? support@plot.ly
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-91700e663fb3> in <module>()
#       2             y=df.gap)]
#       3
# ----> 4 py.iplot(data, filename='jupyter/basic_bar')
#
# C:\ProgramData\Anaconda2\lib\site-packages\plotly\plotly\plotly.pyc in iplot(figure_or_data, **plot_options)
#     107     res = plot(figure_or_data, **plot_options)
#     108     urlsplit = res.split('/')
# --> 109     username, plot_id = urlsplit[-2][1:], urlsplit[-1]  # TODO: HACKY!
#     110
#     111     embed_options = dict()
#
# IndexError: list index out of range
