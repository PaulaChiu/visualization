# %%
import bokeh
bokeh.__version__
# Out:
# u'0.12.5'

# %% [markdown]
# ## open a new browser

# %%
from bokeh.plotting import figure, output_file, show

# %%
output_file("test.html")

# %%
p = figure()
p.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], line_width=2)
show(p)

# %% [markdown]
# ## results in notebook

# %%
from bokeh.plotting import figure, output_notebook, show

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="78cb0204-9a2c-4ab5-a877-aa2795aff707">Loading BokehJS ...</span>
#     </div>

# %%
p = figure()
p.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], line_width=2)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b335cdaf-088a-41b9-a1b3-dc7cb2f36694"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b335cdaf-088a-41b9-a1b3-dc7cb2f36694");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b335cdaf-088a-41b9-a1b3-dc7cb2f36694");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b335cdaf-088a-41b9-a1b3-dc7cb2f36694' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5a001a6f-7dde-46a0-9f0c-7edae60d0cb1":{"roots":{"references":[{"attributes":{"plot":{"id":"afdc719f-5341-4f86-ad78-bce9abd285f0","subtype":"Figure","type":"Plot"}},"id":"701cff12-50ee-404b-8f0c-b4bca63371bb","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e5b2f71f-68fe-463c-ac66-44e8cc74ed25","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"e5b2f71f-68fe-463c-ac66-44e8cc74ed25","type":"BoxAnnotation"},"plot":{"id":"afdc719f-5341-4f86-ad78-bce9abd285f0","subtype":"Figure","type":"Plot"}},"id":"6e1ec6b2-aa4c-4309-9ea6-93b3918a38d8","type":"BoxZoomTool"},{"attributes":{},"id":"07b84d7d-6498-484a-acd3-b47c29404dbd","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"00c4e4f3-f154-4e67-805f-d7bdb59c666e","type":"LinearAxis"}],"left":[{"id":"26ec47b4-a0e2-4806-bf83-59cf79105596","type":"LinearAxis"}],"renderers":[{"id":"00c4e4f3-f154-4e67-805f-d7bdb59c666e","type":"LinearAxis"},{"id":"50032db4-2bee-478c-98fc-000d57aca1e9","type":"Grid"},{"id":"26ec47b4-a0e2-4806-bf83-59cf79105596","type":"LinearAxis"},{"id":"028ee77a-2bf9-43d8-b6d9-31097d765e21","type":"Grid"},{"id":"e5b2f71f-68fe-463c-ac66-44e8cc74ed25","type":"BoxAnnotation"},{"id":"446b8c61-bca6-4ce3-9c0a-ffdbb03e8c89","type":"GlyphRenderer"}],"title":{"id":"f4643813-f895-4878-8383-dfd65c725b28","type":"Title"},"tool_events":{"id":"ebc28f9b-5d08-4e44-8eee-93b1f0d244cc","type":"ToolEvents"},"toolbar":{"id":"1ca01276-92a5-4360-a414-4be751123c03","type":"Toolbar"},"x_range":{"id":"5cd10c84-e3e5-44d3-a7fc-7c4199d426f8","type":"DataRange1d"},"y_range":{"id":"9c0037f8-7088-45e0-ac8c-18f9f86e9902","type":"DataRange1d"}},"id":"afdc719f-5341-4f86-ad78-bce9abd285f0","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"ebc28f9b-5d08-4e44-8eee-93b1f0d244cc","type":"ToolEvents"},{"attributes":{"callback":null},"id":"9c0037f8-7088-45e0-ac8c-18f9f86e9902","type":"DataRange1d"},{"attributes":{"plot":{"id":"afdc719f-5341-4f86-ad78-bce9abd285f0","subtype":"Figure","type":"Plot"}},"id":"77c2483a-fe01-48ae-bf67-89650d4280c1","type":"PanTool"},{"attributes":{"dimension":1,"plot":{"id":"afdc719f-5341-4f86-ad78-bce9abd285f0","subtype":"Figure","type":"Plot"},"ticker":{"id":"ba32306c-532b-4986-a4ea-42895618ac26","type":"BasicTicker"}},"id":"028ee77a-2bf9-43d8-b6d9-31097d765e21","type":"Grid"},{"attributes":{"plot":{"id":"afdc719f-5341-4f86-ad78-bce9abd285f0","subtype":"Figure","type":"Plot"},"ticker":{"id":"8914cc58-7d92-481c-b687-adfc2fe19cc4","type":"BasicTicker"}},"id":"50032db4-2bee-478c-98fc-000d57aca1e9","type":"Grid"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[1,2,3,4,5],"y":[6,7,2,4,5]}},"id":"df12018e-4fab-4e89-8a53-310b78c3324b","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"df12018e-4fab-4e89-8a53-310b78c3324b","type":"ColumnDataSource"},"glyph":{"id":"f29b040f-4971-4cd1-b91f-815021413659","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"b0145141-4468-4dd2-a451-bb4a3ba8c4dc","type":"Line"},"selection_glyph":null},"id":"446b8c61-bca6-4ce3-9c0a-ffdbb03e8c89","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"afdc719f-5341-4f86-ad78-bce9abd285f0","subtype":"Figure","type":"Plot"}},"id":"42a40204-14b7-4f37-8f17-9998a6c64cd0","type":"SaveTool"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"f29b040f-4971-4cd1-b91f-815021413659","type":"Line"},{"attributes":{"plot":{"id":"afdc719f-5341-4f86-ad78-bce9abd285f0","subtype":"Figure","type":"Plot"}},"id":"47cc2ddf-fbee-43bb-9a21-d76fc3aeb0a7","type":"ResetTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"fi ...
